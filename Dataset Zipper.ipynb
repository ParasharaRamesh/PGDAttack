# %%
# !pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (2.137.0)
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.144.0-py2.py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (2.27.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (2.19.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.65.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.20.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.24.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.1.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2024.8.30)
# Downloading google_api_python_client-2.144.0-py2.py3-none-any.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 114.7 MB/s eta 0:00:00
# Installing collected packages: google-api-python-client
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.137.0
#     Uninstalling google-api-python-client-2.137.0:
#       Successfully uninstalled google-api-python-client-2.137.0
# Successfully installed google-api-python-client-2.144.0

# %%
import os
import pickle
import google.auth
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build

# If modifying these SCOPES, delete the file token.pickle.
SCOPES = ['https://www.googleapis.com/auth/drive']

def authenticate_drive():
    creds = None
    # The file token.pickle stores the user's access and refresh tokens.
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        # else:
        #     flow = InstalledAppFlow.from_client_secrets_file('credentials.json', SCOPES)
        #     creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)

    return creds

creds = authenticate_drive()
drive_service = build('drive', 'v3', credentials=creds)

# %%
def empty_trash(drive_service):
    try:
        # Call the Drive API to delete all files in Trash
        drive_service.files().emptyTrash().execute()
        print("Trash emptied successfully.")
    except Exception as e:
        print(f"An error occurred: {e}")

empty_trash(drive_service)
# Out:
# An error occurred: ("Failed to retrieve http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true from the Google Compute Engine metadata service. Status: 404 Response:\nb''", <google_auth_httplib2._Response object at 0x7a4012bae620>)

# %% [markdown]
# Clearing trash from drive is above

# %%
import os
import uuid
import random
from tqdm.auto import tqdm
import copy
import shutil
import zipfile

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
base_path = "/content/drive/MyDrive/trustworthyml"
data_path = os.path.join(base_path, "data")
zips_path = os.path.join(base_path, "zips")

local_path = "/content/dataset"
local_zips_path = "/content/zips"

# %%
total, used, free = shutil.disk_usage("/content/sample_data")
print(f"Total: {total // (2**30)} GiB")
print(f"Used: {used // (2**30)} GiB")
print(f"Free: {free // (2**30)} GiB")
# Out:
# Total: 225 GiB
# Used: 33 GiB
# Free: 192 GiB

# %%
def zip_folder(folder_path, output_zip_path):
    """Zips the contents of a folder into a zip file."""
    print(f"Zipping folder {folder_path} to {output_zip_path}")
    with zipfile.ZipFile(output_zip_path, "w") as zip_file:
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                zip_file.write(file_path)
    print(f"Created zip in {output_zip_path}")

def process_batch(batch_files, local_path, local_zips_path, batch_num, zips_path):
    """Processes a single batch of files: copies, zips, and cleans up."""
    # Copy files to local
    for file in batch_files:
        shutil.copy(file, local_path)
    print(f"Copied {len(batch_files)} files to local")

    # Zip the batch
    local_zip_path = os.path.join(local_zips_path, f"batch_{batch_num + 1}.zip")
    zip_folder(local_path, local_zip_path)
    print(f"Zipped batch {batch_num + 1} to {local_zip_path}")

    # Copy zip to Google Drive
    shutil.copy(local_zip_path, zips_path)
    print(f"Copied zip from {local_zip_path} to {zips_path}")

    # Clean up: delete local zip and copied files
    os.remove(local_zip_path)
    for file in batch_files:
        os.remove(os.path.join(local_path, os.path.basename(file)))
    print(f"Cleaned up batch {batch_num + 1}")

def copy_and_zip_batches(data_path, local_path, local_zips_path, zips_path, batch_size, limit=False):
    """Copies files in batches, zips them, and saves to Google Drive."""
    os.makedirs(local_path, exist_ok=True)
    os.makedirs(local_zips_path, exist_ok=True)
    os.makedirs(zips_path, exist_ok=True)

    if limit:
        print(f"Limiting to first 100 files only")
        all_files = [os.path.join(data_path, f) for f in os.listdir(data_path)][:100]
    else:
        print(f"No limit")
        all_files = [os.path.join(data_path, f) for f in os.listdir(data_path)]

    print(f"Finished listing directory, total is {len(all_files)}")
    total_batches = len(all_files) // batch_size + (len(all_files) % batch_size > 0)

    print(f"Total batches to process: {total_batches}")

    for batch_num in tqdm(range(total_batches), desc="Processing Batches"):
        print("-" * 50)
        print(f"Processing batch {batch_num + 1}/{total_batches}")

        # Determine the start and end index for the current batch
        start_index = batch_num * batch_size
        end_index = min(start_index + batch_size, len(all_files))
        batch_files = all_files[start_index:end_index]

        # Process the current batch
        process_batch(batch_files, local_path, local_zips_path, batch_num, zips_path)

    print(f"Finished processing all batches!")

# %%
batch = 200
copy_and_zip_batches(data_path, local_path, local_zips_path, zips_path, batch, False)
print(f"Finished copying to drive")
# Out:
# No limit
# Finished listing directory, total is 32880
# Total batches to process: 165
# Processing Batches:   0%|          | 0/165 [00:00<?, ?it/s]
# --------------------------------------------------
# Processing batch 1/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_1.zip
# Created zip in /content/zips/batch_1.zip
# Zipped batch 1 to /content/zips/batch_1.zip
# Copied zip from /content/zips/batch_1.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 1
# --------------------------------------------------
# Processing batch 2/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_2.zip
# Created zip in /content/zips/batch_2.zip
# Zipped batch 2 to /content/zips/batch_2.zip
# Copied zip from /content/zips/batch_2.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 2
# --------------------------------------------------
# Processing batch 3/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_3.zip
# Created zip in /content/zips/batch_3.zip
# Zipped batch 3 to /content/zips/batch_3.zip
# Copied zip from /content/zips/batch_3.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 3
# --------------------------------------------------
# Processing batch 4/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_4.zip
# Created zip in /content/zips/batch_4.zip
# Zipped batch 4 to /content/zips/batch_4.zip
# Copied zip from /content/zips/batch_4.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 4
# --------------------------------------------------
# Processing batch 5/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_5.zip
# Created zip in /content/zips/batch_5.zip
# Zipped batch 5 to /content/zips/batch_5.zip
# Copied zip from /content/zips/batch_5.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 5
# --------------------------------------------------
# Processing batch 6/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_6.zip
# Created zip in /content/zips/batch_6.zip
# Zipped batch 6 to /content/zips/batch_6.zip
# Copied zip from /content/zips/batch_6.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 6
# --------------------------------------------------
# Processing batch 7/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_7.zip
# Created zip in /content/zips/batch_7.zip
# Zipped batch 7 to /content/zips/batch_7.zip
# Copied zip from /content/zips/batch_7.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 7
# --------------------------------------------------
# Processing batch 8/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_8.zip
# Created zip in /content/zips/batch_8.zip
# Zipped batch 8 to /content/zips/batch_8.zip
# Copied zip from /content/zips/batch_8.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 8
# --------------------------------------------------
# Processing batch 9/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_9.zip
# Created zip in /content/zips/batch_9.zip
# Zipped batch 9 to /content/zips/batch_9.zip
# Copied zip from /content/zips/batch_9.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 9
# --------------------------------------------------
# Processing batch 10/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_10.zip
# Created zip in /content/zips/batch_10.zip
# Zipped batch 10 to /content/zips/batch_10.zip
# Copied zip from /content/zips/batch_10.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 10
# --------------------------------------------------
# Processing batch 11/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_11.zip
# Created zip in /content/zips/batch_11.zip
# Zipped batch 11 to /content/zips/batch_11.zip
# Copied zip from /content/zips/batch_11.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 11
# --------------------------------------------------
# Processing batch 12/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_12.zip
# Created zip in /content/zips/batch_12.zip
# Zipped batch 12 to /content/zips/batch_12.zip
# Copied zip from /content/zips/batch_12.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 12
# --------------------------------------------------
# Processing batch 13/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_13.zip
# Created zip in /content/zips/batch_13.zip
# Zipped batch 13 to /content/zips/batch_13.zip
# Copied zip from /content/zips/batch_13.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 13
# --------------------------------------------------
# Processing batch 14/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_14.zip
# Created zip in /content/zips/batch_14.zip
# Zipped batch 14 to /content/zips/batch_14.zip
# Copied zip from /content/zips/batch_14.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 14
# --------------------------------------------------
# Processing batch 15/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_15.zip
# Created zip in /content/zips/batch_15.zip
# Zipped batch 15 to /content/zips/batch_15.zip
# Copied zip from /content/zips/batch_15.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 15
# --------------------------------------------------
# Processing batch 16/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_16.zip
# Created zip in /content/zips/batch_16.zip
# Zipped batch 16 to /content/zips/batch_16.zip
# Copied zip from /content/zips/batch_16.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 16
# --------------------------------------------------
# Processing batch 17/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_17.zip
# Created zip in /content/zips/batch_17.zip
# Zipped batch 17 to /content/zips/batch_17.zip
# Copied zip from /content/zips/batch_17.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 17
# --------------------------------------------------
# Processing batch 18/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_18.zip
# Created zip in /content/zips/batch_18.zip
# Zipped batch 18 to /content/zips/batch_18.zip
# Copied zip from /content/zips/batch_18.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 18
# --------------------------------------------------
# Processing batch 19/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_19.zip
# Created zip in /content/zips/batch_19.zip
# Zipped batch 19 to /content/zips/batch_19.zip
# Copied zip from /content/zips/batch_19.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 19
# --------------------------------------------------
# Processing batch 20/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_20.zip
# Created zip in /content/zips/batch_20.zip
# Zipped batch 20 to /content/zips/batch_20.zip
# Copied zip from /content/zips/batch_20.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 20
# --------------------------------------------------
# Processing batch 21/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_21.zip
# Created zip in /content/zips/batch_21.zip
# Zipped batch 21 to /content/zips/batch_21.zip
# Copied zip from /content/zips/batch_21.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 21
# --------------------------------------------------
# Processing batch 22/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_22.zip
# Created zip in /content/zips/batch_22.zip
# Zipped batch 22 to /content/zips/batch_22.zip
# Copied zip from /content/zips/batch_22.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 22
# --------------------------------------------------
# Processing batch 23/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_23.zip
# Created zip in /content/zips/batch_23.zip
# Zipped batch 23 to /content/zips/batch_23.zip
# Copied zip from /content/zips/batch_23.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 23
# --------------------------------------------------
# Processing batch 24/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_24.zip
# Created zip in /content/zips/batch_24.zip
# Zipped batch 24 to /content/zips/batch_24.zip
# Copied zip from /content/zips/batch_24.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 24
# --------------------------------------------------
# Processing batch 25/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_25.zip
# Created zip in /content/zips/batch_25.zip
# Zipped batch 25 to /content/zips/batch_25.zip
# Copied zip from /content/zips/batch_25.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 25
# --------------------------------------------------
# Processing batch 26/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_26.zip
# Created zip in /content/zips/batch_26.zip
# Zipped batch 26 to /content/zips/batch_26.zip
# Copied zip from /content/zips/batch_26.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 26
# --------------------------------------------------
# Processing batch 27/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_27.zip
# Created zip in /content/zips/batch_27.zip
# Zipped batch 27 to /content/zips/batch_27.zip
# Copied zip from /content/zips/batch_27.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 27
# --------------------------------------------------
# Processing batch 28/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_28.zip
# Created zip in /content/zips/batch_28.zip
# Zipped batch 28 to /content/zips/batch_28.zip
# Copied zip from /content/zips/batch_28.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 28
# --------------------------------------------------
# Processing batch 29/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_29.zip
# Created zip in /content/zips/batch_29.zip
# Zipped batch 29 to /content/zips/batch_29.zip
# Copied zip from /content/zips/batch_29.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 29
# --------------------------------------------------
# Processing batch 30/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_30.zip
# Created zip in /content/zips/batch_30.zip
# Zipped batch 30 to /content/zips/batch_30.zip
# Copied zip from /content/zips/batch_30.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 30
# --------------------------------------------------
# Processing batch 31/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_31.zip
# Created zip in /content/zips/batch_31.zip
# Zipped batch 31 to /content/zips/batch_31.zip
# Copied zip from /content/zips/batch_31.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 31
# --------------------------------------------------
# Processing batch 32/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_32.zip
# Created zip in /content/zips/batch_32.zip
# Zipped batch 32 to /content/zips/batch_32.zip
# Copied zip from /content/zips/batch_32.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 32
# --------------------------------------------------
# Processing batch 33/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_33.zip
# Created zip in /content/zips/batch_33.zip
# Zipped batch 33 to /content/zips/batch_33.zip
# Copied zip from /content/zips/batch_33.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 33
# --------------------------------------------------
# Processing batch 34/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_34.zip
# Created zip in /content/zips/batch_34.zip
# Zipped batch 34 to /content/zips/batch_34.zip
# Copied zip from /content/zips/batch_34.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 34
# --------------------------------------------------
# Processing batch 35/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_35.zip
# Created zip in /content/zips/batch_35.zip
# Zipped batch 35 to /content/zips/batch_35.zip
# Copied zip from /content/zips/batch_35.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 35
# --------------------------------------------------
# Processing batch 36/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_36.zip
# Created zip in /content/zips/batch_36.zip
# Zipped batch 36 to /content/zips/batch_36.zip
# Copied zip from /content/zips/batch_36.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 36
# --------------------------------------------------
# Processing batch 37/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_37.zip
# Created zip in /content/zips/batch_37.zip
# Zipped batch 37 to /content/zips/batch_37.zip
# Copied zip from /content/zips/batch_37.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 37
# --------------------------------------------------
# Processing batch 38/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_38.zip
# Created zip in /content/zips/batch_38.zip
# Zipped batch 38 to /content/zips/batch_38.zip
# Copied zip from /content/zips/batch_38.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 38
# --------------------------------------------------
# Processing batch 39/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_39.zip
# Created zip in /content/zips/batch_39.zip
# Zipped batch 39 to /content/zips/batch_39.zip
# Copied zip from /content/zips/batch_39.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 39
# --------------------------------------------------
# Processing batch 40/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_40.zip
# Created zip in /content/zips/batch_40.zip
# Zipped batch 40 to /content/zips/batch_40.zip
# Copied zip from /content/zips/batch_40.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 40
# --------------------------------------------------
# Processing batch 41/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_41.zip
# Created zip in /content/zips/batch_41.zip
# Zipped batch 41 to /content/zips/batch_41.zip
# Copied zip from /content/zips/batch_41.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 41
# --------------------------------------------------
# Processing batch 42/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_42.zip
# Created zip in /content/zips/batch_42.zip
# Zipped batch 42 to /content/zips/batch_42.zip
# Copied zip from /content/zips/batch_42.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 42
# --------------------------------------------------
# Processing batch 43/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_43.zip
# Created zip in /content/zips/batch_43.zip
# Zipped batch 43 to /content/zips/batch_43.zip
# Copied zip from /content/zips/batch_43.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 43
# --------------------------------------------------
# Processing batch 44/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_44.zip
# Created zip in /content/zips/batch_44.zip
# Zipped batch 44 to /content/zips/batch_44.zip
# Copied zip from /content/zips/batch_44.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 44
# --------------------------------------------------
# Processing batch 45/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_45.zip
# Created zip in /content/zips/batch_45.zip
# Zipped batch 45 to /content/zips/batch_45.zip
# Copied zip from /content/zips/batch_45.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 45
# --------------------------------------------------
# Processing batch 46/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_46.zip
# Created zip in /content/zips/batch_46.zip
# Zipped batch 46 to /content/zips/batch_46.zip
# Copied zip from /content/zips/batch_46.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 46
# --------------------------------------------------
# Processing batch 47/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_47.zip
# Created zip in /content/zips/batch_47.zip
# Zipped batch 47 to /content/zips/batch_47.zip
# Copied zip from /content/zips/batch_47.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 47
# --------------------------------------------------
# Processing batch 48/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_48.zip
# Created zip in /content/zips/batch_48.zip
# Zipped batch 48 to /content/zips/batch_48.zip
# Copied zip from /content/zips/batch_48.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 48
# --------------------------------------------------
# Processing batch 49/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_49.zip
# Created zip in /content/zips/batch_49.zip
# Zipped batch 49 to /content/zips/batch_49.zip
# Copied zip from /content/zips/batch_49.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 49
# --------------------------------------------------
# Processing batch 50/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_50.zip
# Created zip in /content/zips/batch_50.zip
# Zipped batch 50 to /content/zips/batch_50.zip
# Copied zip from /content/zips/batch_50.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 50
# --------------------------------------------------
# Processing batch 51/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_51.zip
# Created zip in /content/zips/batch_51.zip
# Zipped batch 51 to /content/zips/batch_51.zip
# Copied zip from /content/zips/batch_51.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 51
# --------------------------------------------------
# Processing batch 52/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_52.zip
# Created zip in /content/zips/batch_52.zip
# Zipped batch 52 to /content/zips/batch_52.zip
# Copied zip from /content/zips/batch_52.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 52
# --------------------------------------------------
# Processing batch 53/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_53.zip
# Created zip in /content/zips/batch_53.zip
# Zipped batch 53 to /content/zips/batch_53.zip
# Copied zip from /content/zips/batch_53.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 53
# --------------------------------------------------
# Processing batch 54/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_54.zip
# Created zip in /content/zips/batch_54.zip
# Zipped batch 54 to /content/zips/batch_54.zip
# Copied zip from /content/zips/batch_54.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 54
# --------------------------------------------------
# Processing batch 55/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_55.zip
# Created zip in /content/zips/batch_55.zip
# Zipped batch 55 to /content/zips/batch_55.zip
# Copied zip from /content/zips/batch_55.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 55
# --------------------------------------------------
# Processing batch 56/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_56.zip
# Created zip in /content/zips/batch_56.zip
# Zipped batch 56 to /content/zips/batch_56.zip
# Copied zip from /content/zips/batch_56.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 56
# --------------------------------------------------
# Processing batch 57/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_57.zip
# Created zip in /content/zips/batch_57.zip
# Zipped batch 57 to /content/zips/batch_57.zip
# Copied zip from /content/zips/batch_57.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 57
# --------------------------------------------------
# Processing batch 58/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_58.zip
# Created zip in /content/zips/batch_58.zip
# Zipped batch 58 to /content/zips/batch_58.zip
# Copied zip from /content/zips/batch_58.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 58
# --------------------------------------------------
# Processing batch 59/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_59.zip
# Created zip in /content/zips/batch_59.zip
# Zipped batch 59 to /content/zips/batch_59.zip
# Copied zip from /content/zips/batch_59.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 59
# --------------------------------------------------
# Processing batch 60/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_60.zip
# Created zip in /content/zips/batch_60.zip
# Zipped batch 60 to /content/zips/batch_60.zip
# Copied zip from /content/zips/batch_60.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 60
# --------------------------------------------------
# Processing batch 61/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_61.zip
# Created zip in /content/zips/batch_61.zip
# Zipped batch 61 to /content/zips/batch_61.zip
# Copied zip from /content/zips/batch_61.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 61
# --------------------------------------------------
# Processing batch 62/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_62.zip
# Created zip in /content/zips/batch_62.zip
# Zipped batch 62 to /content/zips/batch_62.zip
# Copied zip from /content/zips/batch_62.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 62
# --------------------------------------------------
# Processing batch 63/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_63.zip
# Created zip in /content/zips/batch_63.zip
# Zipped batch 63 to /content/zips/batch_63.zip
# Copied zip from /content/zips/batch_63.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 63
# --------------------------------------------------
# Processing batch 64/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_64.zip
# Created zip in /content/zips/batch_64.zip
# Zipped batch 64 to /content/zips/batch_64.zip
# Copied zip from /content/zips/batch_64.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 64
# --------------------------------------------------
# Processing batch 65/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_65.zip
# Created zip in /content/zips/batch_65.zip
# Zipped batch 65 to /content/zips/batch_65.zip
# Copied zip from /content/zips/batch_65.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 65
# --------------------------------------------------
# Processing batch 66/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_66.zip
# Created zip in /content/zips/batch_66.zip
# Zipped batch 66 to /content/zips/batch_66.zip
# Copied zip from /content/zips/batch_66.zip to /content/drive/MyDrive/trustworthyml/zips
# Cleaned up batch 66
# --------------------------------------------------
# Processing batch 67/165
# Copied 200 files to local
# Zipping folder /content/dataset to /content/zips/batch_67.zip

# %% [markdown]
# Code to get all zips into local instance and unzip it

# %%
def unzip_files(zip_folder_path, extract_to_path):
    """Unzips all zip files in the specified folder to the given extraction path."""
    zip_files = [os.path.join(zip_folder_path, zip_file) for zip_file in os.listdir(zip_folder_path) if zip_file.endswith('.zip')]
    print(f"Found {len(zip_files)} zip files to unzip.")

    for zip_file_path in tqdm(zip_files, desc="Unzipping Files"):
        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            # Extract each file individually to avoid creating nested folders
            for file_info in zip_ref.infolist():
                # Only extract files, not directories
                if not file_info.is_dir():
                    extracted_file_path = os.path.join(extract_to_path, os.path.basename(file_info.filename))
                    zip_ref.extract(file_info, extract_to_path)
                    # Move the extracted file to the target location without the directory structure
                    shutil.move(os.path.join(extract_to_path, file_info.filename), extracted_file_path)
                    # Remove the original extracted file (with directory structure)
        print(f"Unzipped {zip_file_path} to {extract_to_path}")
    toremove = os.path.join(extract_to_path, "content")
    if os.path.exists(toremove):
      shutil.rmtree(toremove)
      # os.rmdir(toremove)
      print(f"Deleted empty directory {toremove}")
    else:
      print(f"No empty directory found at {toremove}")

def copy_and_unzip_from_drive(drive_zips_path, local_zips_path, extract_to_path):
    """Copies zip files from Google Drive to local and unzips them."""
    print(f"Copying files from {drive_zips_path} to {local_zips_path} and then unzipping to {extract_to_path}")

    # Create local zip directory if it doesn't exist
    os.makedirs(local_zips_path, exist_ok=True)
    os.makedirs(extract_to_path, exist_ok=True)

    # List all zip files in the Google Drive zips directory
    zip_files = [f for f in os.listdir(drive_zips_path) if f.endswith('.zip')]
    print(f"Found {len(zip_files)} zip files in Google Drive.")

    for zip_file in tqdm(zip_files, desc="Copying and Unzipping"):
        zip_file_path = os.path.join(drive_zips_path, zip_file)
        local_zip_path = os.path.join(local_zips_path, zip_file)

        # Copy zip file to local
        shutil.copy(zip_file_path, local_zip_path)
        print(f"Copied {zip_file} to local.")

        # Unzip the file
        unzip_files(local_zips_path, extract_to_path)

# %%
new_local_path = "/content/new_dataset"
new_local_zips_path = "/content/new_zips"
copy_and_unzip_from_drive(zips_path, new_local_zips_path, new_local_path)
# Out:
# Copying files from /content/drive/MyDrive/trustworthyml/zips to /content/new_zips and then unzipping to /content/new_dataset
# Found 3 zip files in Google Drive.
# Copying and Unzipping:   0%|          | 0/3 [00:00<?, ?it/s]
# Copied batch_1.zip to local.
# Found 1 zip files to unzip.
# Unzipping Files:   0%|          | 0/1 [00:00<?, ?it/s]
# Unzipped /content/new_zips/batch_1.zip to /content/new_dataset
# Deleted empty directory /content/new_dataset/content
# Copied batch_2.zip to local.
# Found 2 zip files to unzip.
# Unzipping Files:   0%|          | 0/2 [00:00<?, ?it/s]
# Unzipped /content/new_zips/batch_1.zip to /content/new_dataset
# Unzipped /content/new_zips/batch_2.zip to /content/new_dataset
# Deleted empty directory /content/new_dataset/content
# Copied batch_3.zip to local.
# Found 3 zip files to unzip.
# Unzipping Files:   0%|          | 0/3 [00:00<?, ?it/s]
# Unzipped /content/new_zips/batch_1.zip to /content/new_dataset
# Unzipped /content/new_zips/batch_3.zip to /content/new_dataset
# Unzipped /content/new_zips/batch_2.zip to /content/new_dataset
# Deleted empty directory /content/new_dataset/content

# %%
# !rm -r /content/new_dataset
# !rm -r /content/new_zips

# %%
len(os.listdir(new_local_path))
# Out:
# 30
